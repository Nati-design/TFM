# %%
## Conjunto completo de nodos ##
#[{'nodo': 'parking', 'nombre': 'ES08191 Rubi', 'direccion': 'Ctra. Molins de Rei, 251, Km. 8, 08191 Rubí, Barcelona'}, 
#{'nodo': 'carga', 'nombre': 'ES08840 Viladecans', 'direccion': 'Av. del Segle XXI, 63, 08840 Viladecans, Barcelona'}, 
#{'nodo': 'carga', 'nombre': 'ES08272 Sant Fruitós de Bages', 'direccion': 'Carrer Sakura, 16B, NAVE 16A, 08272 Sant Fruitós de Bages, Barcelona'},
#{'nodo': 'carga', 'nombre': 'ES08650 Sallent', 'direccion': "Avinguda Can Montcau, 1-3-5, 08186 Lliçà d'Amunt, Barcelona"},
#
# {'nodo': 'carga', 'nombre': 'ES08186 Lliça de Amunt', 'direccion': "Carrer d'Anselm Clavé, 62 AB, 08186 Lliçà d'Amunt, Barcelona"}, 
#{'nodo' : 'carga', 'nombre' :	'ES8740 Sant Andreu de la Barca', 'direccion': 'Carrer Ferralla, 24, 08755 Castellbisbal, Barcelona'},
#{'nodo' : 'carga', 'nombre' :	'ES8739 Casablanca', 'direccion': 'Pol. Ind. Can Bosch, Mod, 2, 3/4, 08739, Barcelona'},
#{'nodo' : 'carga', 'nombre' :	'ES8755 Castellbisbal', 'direccion': 'Carrer Ferralla 14'},
#{'nodo' : 'carga', 'nombre' :	'ES8130 Santa Perpètua de Mogoda', 'direccion': ' POL.IND. LES MINITES, PARCELA2-3, CIM DEL VALLÉS'},
#{'nodo' : 'carga', 'nombre' :	'ES8170 Montornès del Vallès', 'direccion': ' Carrer d\'Edison, 16'},
#{'nodo' : 'carga', 'nombre' :	'ES8755 Castellbisbal', 'direccion': 'Carrer Manganès 2'},
#
# {'nodo': 'descarga', 'nombre': 'ES08040 Barcelona', 'direccion': 'DHL FREIGHT SPAIN S.L, C/ Atlantic 109-111  (ZAL)'}, 
#{'nodo': 'cargador', 'nombre': 'IONITY Palleja', 'direccion': 'Ronda de Santa Eulàlia, 31, 08780 Pallejà, Barcelona'}, 
#{'nodo': 'cargador', 'nombre': 'IONITY Barcera del Valles', 'direccion': ''}, 
#{'nodo': 'cargador', 'nombre': 'IONITY Montcada i Reixac', 'direccion': ''}, 
#{'nodo': 'cargador', 'nombre': 'Atlante - Nieves Zona Franca', 'direccion': ''}, 
#{'nodo': 'cargador', 'nombre': 'Atlante - Atlante - Nieves Sant Esteve', 'direccion': ''}]

# %%
# Dataset original (4 puntos)
import pickle

datos_1 = [
    {'nodo': 'parking', 'nombre': 'ES08191 Rubi', 'direccion': 'Ctra. Molins de Rei, 251, Km. 8, 08191 Rubí, Barcelona'},
    {'nodo': 'carga', 'nombre': 'ES08840 Viladecans', 'direccion': 'Av. del Segle XXI, 63, 08840 Viladecans, Barcelona'},
    {'nodo': 'carga', 'nombre': 'ES08272 Sant Fruitós de Bages', 'direccion': 'Carrer Sakura, 16B, NAVE 16A, 08272 Sant Fruitós de Bages, Barcelona'},
    {'nodo': 'carga', 'nombre': 'ES08650 Sallent', 'direccion': "Avinguda Can Montcau, 1-3-5, 08186 Lliçà d'Amunt, Barcelona"},
    {'nodo': 'carga', 'nombre': 'ES08186 Lliça de Amunt', 'direccion': "Carrer d'Anselm Clavé, 62 AB, 08186 Lliçà d'Amunt, Barcelona"},
    {'nodo': 'descarga', 'nombre': 'ES08040 Barcelona', 'direccion': 'DHL FREIGHT SPAIN S.L, C/ Atlantic 109-111  (ZAL)'},
    {'nodo': 'cargador', 'nombre': 'IONITY Palleja', 'direccion': 'Ronda de Santa Eulàlia, 31, 08780 Pallejà, Barcelona'},
    {'nodo': 'cargador', 'nombre': 'IONITY Barcera del Valles', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'IONITY Montcada i Reixac', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Nieves Zona Franca', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Atlante - Nieves Sant Esteve', 'direccion': ''}
]

with open("dataset_dhl_1.pkl", "wb") as f:
    pickle.dump(datos_1, f)

# %%
# Dataset 3 puntos
import pickle

datos_2 = [
    {'nodo': 'parking', 'nombre': 'ES08191 Rubi', 'direccion': 'Ctra. Molins de Rei, 251, Km. 8, 08191 Rubí, Barcelona'},
    {'nodo': 'carga', 'nombre': 'ES08650 Sallent', 'direccion': "Avinguda Can Montcau, 1-3-5, 08186 Lliçà d'Amunt, Barcelona"},
    {'nodo': 'carga', 'nombre': 'ES08186 Lliça de Amunt', 'direccion': "Carrer d'Anselm Clavé, 62 AB, 08186 Lliçà d'Amunt, Barcelona"}, 
    {'nodo' : 'carga', 'nombre' :	'ES8740 Sant Andreu de la Barca', 'direccion': 'Carrer Ferralla, 24, 08755 Castellbisbal, Barcelona'},
    {'nodo': 'descarga', 'nombre': 'ES08040 Barcelona', 'direccion': 'DHL FREIGHT SPAIN S.L, C/ Atlantic 109-111  (ZAL)'},
    {'nodo': 'cargador', 'nombre': 'IONITY Palleja', 'direccion': 'Ronda de Santa Eulàlia, 31, 08780 Pallejà, Barcelona'},
    {'nodo': 'cargador', 'nombre': 'IONITY Barcera del Valles', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'IONITY Montcada i Reixac', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Nieves Zona Franca', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Atlante - Nieves Sant Esteve', 'direccion': ''}
]

with open("dataset_dhl_2.pkl", "wb") as f:
    pickle.dump(datos_2, f)

# %%
# Dataset 3 puntos
import pickle

datos_3 = [
    {'nodo': 'parking', 'nombre': 'ES08191 Rubi', 'direccion': 'Ctra. Molins de Rei, 251, Km. 8, 08191 Rubí, Barcelona'},
    {'nodo': 'carga', 'nombre': 'ES08186 Lliça de Amunt', 'direccion': "Carrer d'Anselm Clavé, 62 AB, 08186 Lliçà d'Amunt, Barcelona"},         
    {'nodo' : 'carga', 'nombre' :	'ES8740 Sant Andreu de la Barca', 'direccion': 'Carrer Ferralla, 24, 08755 Castellbisbal, Barcelona'},
    {'nodo' : 'carga', 'nombre' :	'ES8739 Casablanca', 'direccion': 'Pol. Ind. Can Bosch, Mod, 2, 3/4, 08739, Barcelona'},
    {'nodo': 'descarga', 'nombre': 'ES08040 Barcelona', 'direccion': 'DHL FREIGHT SPAIN S.L, C/ Atlantic 109-111  (ZAL)'},
    {'nodo': 'cargador', 'nombre': 'IONITY Palleja', 'direccion': 'Ronda de Santa Eulàlia, 31, 08780 Pallejà, Barcelona'},
    {'nodo': 'cargador', 'nombre': 'IONITY Barcera del Valles', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'IONITY Montcada i Reixac', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Nieves Zona Franca', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Atlante - Nieves Sant Esteve', 'direccion': ''}
]

with open("dataset_dhl_3.pkl", "wb") as f:
    pickle.dump(datos_3, f)

# %%
# Dataset 3 puntos
import pickle

datos_4 = [
    {'nodo': 'parking', 'nombre': 'ES08191 Rubi', 'direccion': 'Ctra. Molins de Rei, 251, Km. 8, 08191 Rubí, Barcelona'},
    {'nodo' : 'carga', 'nombre' :	'ES8740 Sant Andreu de la Barca', 'direccion': 'Carrer Ferralla, 24, 08755 Castellbisbal, Barcelona'},
    {'nodo' : 'carga', 'nombre' :	'ES8739 Casablanca', 'direccion': 'Pol. Ind. Can Bosch, Mod, 2, 3/4, 08739, Barcelona'},
    {'nodo' : 'carga', 'nombre' :	'ES8755 Castellbisbal', 'direccion': 'Carrer Ferralla 14'},
    {'nodo': 'descarga', 'nombre': 'ES08040 Barcelona', 'direccion': 'DHL FREIGHT SPAIN S.L, C/ Atlantic 109-111  (ZAL)'},
    {'nodo': 'cargador', 'nombre': 'IONITY Palleja', 'direccion': 'Ronda de Santa Eulàlia, 31, 08780 Pallejà, Barcelona'},
    {'nodo': 'cargador', 'nombre': 'IONITY Barcera del Valles', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'IONITY Montcada i Reixac', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Nieves Zona Franca', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Atlante - Nieves Sant Esteve', 'direccion': ''}
]

with open("dataset_dhl_4.pkl", "wb") as f:
    pickle.dump(datos_4, f)

# %%
# Dataset 3 puntos
import pickle

datos_5 = [
    {'nodo': 'parking', 'nombre': 'ES08191 Rubi', 'direccion': 'Ctra. Molins de Rei, 251, Km. 8, 08191 Rubí, Barcelona'},
    {'nodo' : 'carga', 'nombre' :	'ES8739 Casablanca', 'direccion': 'Pol. Ind. Can Bosch, Mod, 2, 3/4, 08739, Barcelona'},
    {'nodo' : 'carga', 'nombre' :	'ES8755 Castellbisbal', 'direccion': 'Carrer Ferralla 14'},
    {'nodo' : 'carga', 'nombre' :	'ES8130 Santa Perpètua de Mogoda', 'direccion': ' POL.IND. LES MINITES, PARCELA2-3, CIM DEL VALLÉS'},
    {'nodo': 'descarga', 'nombre': 'ES08040 Barcelona', 'direccion': 'DHL FREIGHT SPAIN S.L, C/ Atlantic 109-111  (ZAL)'},
    {'nodo': 'cargador', 'nombre': 'IONITY Palleja', 'direccion': 'Ronda de Santa Eulàlia, 31, 08780 Pallejà, Barcelona'},
    {'nodo': 'cargador', 'nombre': 'IONITY Barcera del Valles', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'IONITY Montcada i Reixac', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Nieves Zona Franca', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Atlante - Nieves Sant Esteve', 'direccion': ''}
]

with open("dataset_dhl_5.pkl", "wb") as f:
    pickle.dump(datos_5, f)

# %%
# Dataset 3 puntos
import pickle

datos_6 = [
    {'nodo': 'parking', 'nombre': 'ES08191 Rubi', 'direccion': 'Ctra. Molins de Rei, 251, Km. 8, 08191 Rubí, Barcelona'},
    {'nodo' : 'carga', 'nombre' :	'ES8755 Castellbisbal', 'direccion': 'Carrer Ferralla 14'},
    {'nodo' : 'carga', 'nombre' :	'ES8130 Santa Perpètua de Mogoda', 'direccion': ' POL.IND. LES MINITES, PARCELA2-3, CIM DEL VALLÉS'},
    {'nodo' : 'carga', 'nombre' :	'ES8755 Castellbisbal', 'direccion': 'Carrer Manganès 2'},
    {'nodo': 'descarga', 'nombre': 'ES08040 Barcelona', 'direccion': 'DHL FREIGHT SPAIN S.L, C/ Atlantic 109-111  (ZAL)'},
    {'nodo': 'cargador', 'nombre': 'IONITY Palleja', 'direccion': 'Ronda de Santa Eulàlia, 31, 08780 Pallejà, Barcelona'},
    {'nodo': 'cargador', 'nombre': 'IONITY Barcera del Valles', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'IONITY Montcada i Reixac', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Nieves Zona Franca', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Atlante - Nieves Sant Esteve', 'direccion': ''}
]

with open("dataset_dhl_6.pkl", "wb") as f:
    pickle.dump(datos_6, f)

# %%
# Dataset 4 puntos
import pickle

datos_7 = [
    {'nodo': 'parking', 'nombre': 'ES08191 Rubi', 'direccion': 'Ctra. Molins de Rei, 251, Km. 8, 08191 Rubí, Barcelona'},
    {'nodo' : 'carga', 'nombre' :	'ES8755 Castellbisbal', 'direccion': 'Carrer Ferralla 14'},
    {'nodo' : 'carga', 'nombre' :	'ES8130 Santa Perpètua de Mogoda', 'direccion': ' POL.IND. LES MINITES, PARCELA2-3, CIM DEL VALLÉS'},
    {'nodo' : 'carga', 'nombre' :	'ES8170 Montornès del Vallès', 'direccion': ' Carrer d\'Edison, 16'},
    {'nodo' : 'carga', 'nombre' :	'ES8755 Castellbisbal', 'direccion': 'Carrer Manganès 2'},
    {'nodo': 'descarga', 'nombre': 'ES08040 Barcelona', 'direccion': 'DHL FREIGHT SPAIN S.L, C/ Atlantic 109-111  (ZAL)'},
    {'nodo': 'cargador', 'nombre': 'IONITY Palleja', 'direccion': 'Ronda de Santa Eulàlia, 31, 08780 Pallejà, Barcelona'},
    {'nodo': 'cargador', 'nombre': 'IONITY Barcera del Valles', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'IONITY Montcada i Reixac', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Nieves Zona Franca', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Atlante - Nieves Sant Esteve', 'direccion': ''}
]

with open("dataset_dhl_7.pkl", "wb") as f:
    pickle.dump(datos_7, f)

# %%
# Dataset 4 puntos
import pickle

datos_8 = [
    {'nodo': 'parking', 'nombre': 'ES08191 Rubi', 'direccion': 'Ctra. Molins de Rei, 251, Km. 8, 08191 Rubí, Barcelona'},
    {'nodo' : 'carga', 'nombre' :	'ES8739 Casablanca', 'direccion': 'Pol. Ind. Can Bosch, Mod, 2, 3/4, 08739, Barcelona'},
    {'nodo' : 'carga', 'nombre' :	'ES8755 Castellbisbal', 'direccion': 'Carrer Ferralla 14'},
    {'nodo' : 'carga', 'nombre' :	'ES8130 Santa Perpètua de Mogoda', 'direccion': ' POL.IND. LES MINITES, PARCELA2-3, CIM DEL VALLÉS'},
    {'nodo' : 'carga', 'nombre' :	'ES8170 Montornès del Vallès', 'direccion': ' Carrer d\'Edison, 16'},
    {'nodo': 'descarga', 'nombre': 'ES08040 Barcelona', 'direccion': 'DHL FREIGHT SPAIN S.L, C/ Atlantic 109-111  (ZAL)'},
    {'nodo': 'cargador', 'nombre': 'IONITY Palleja', 'direccion': 'Ronda de Santa Eulàlia, 31, 08780 Pallejà, Barcelona'},
    {'nodo': 'cargador', 'nombre': 'IONITY Barcera del Valles', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'IONITY Montcada i Reixac', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Nieves Zona Franca', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Atlante - Nieves Sant Esteve', 'direccion': ''}
]

with open("dataset_dhl_8.pkl", "wb") as f:
    pickle.dump(datos_8, f)

# %%
# Dataset 4 puntos
import pickle

datos_9 = [
    {'nodo': 'parking', 'nombre': 'ES08191 Rubi', 'direccion': 'Ctra. Molins de Rei, 251, Km. 8, 08191 Rubí, Barcelona'},
    {'nodo': 'carga', 'nombre': 'ES08840 Viladecans', 'direccion': 'Av. del Segle XXI, 63, 08840 Viladecans, Barcelona'}, 
    {'nodo': 'carga', 'nombre': 'ES08272 Sant Fruitós de Bages', 'direccion': 'Carrer Sakura, 16B, NAVE 16A, 08272 Sant Fruitós de Bages, Barcelona'},
    {'nodo': 'carga', 'nombre': 'ES08650 Sallent', 'direccion': "Avinguda Can Montcau, 1-3-5, 08186 Lliçà d'Amunt, Barcelona"},
    {'nodo' : 'carga', 'nombre' :	'ES8170 Montornès del Vallès', 'direccion': ' Carrer d\'Edison, 16'},
    {'nodo': 'descarga', 'nombre': 'ES08040 Barcelona', 'direccion': 'DHL FREIGHT SPAIN S.L, C/ Atlantic 109-111  (ZAL)'},
    {'nodo': 'cargador', 'nombre': 'IONITY Palleja', 'direccion': 'Ronda de Santa Eulàlia, 31, 08780 Pallejà, Barcelona'},
    {'nodo': 'cargador', 'nombre': 'IONITY Barcera del Valles', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'IONITY Montcada i Reixac', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Nieves Zona Franca', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Atlante - Nieves Sant Esteve', 'direccion': ''}
]

with open("dataset_dhl_9.pkl", "wb") as f:
    pickle.dump(datos_9, f)

# %%
# Dataset 4 puntos
import pickle

datos_10 = [
    {'nodo': 'parking', 'nombre': 'ES08191 Rubi', 'direccion': 'Ctra. Molins de Rei, 251, Km. 8, 08191 Rubí, Barcelona'},
    {'nodo': 'carga', 'nombre': 'ES08840 Viladecans', 'direccion': 'Av. del Segle XXI, 63, 08840 Viladecans, Barcelona'}, 
    {'nodo': 'carga', 'nombre': 'ES08272 Sant Fruitós de Bages', 'direccion': 'Carrer Sakura, 16B, NAVE 16A, 08272 Sant Fruitós de Bages, Barcelona'},
    {'nodo': 'carga', 'nombre': 'ES08650 Sallent', 'direccion': "Avinguda Can Montcau, 1-3-5, 08186 Lliçà d'Amunt, Barcelona"},
    {'nodo' : 'carga', 'nombre' :	'ES8739 Casablanca', 'direccion': 'Pol. Ind. Can Bosch, Mod, 2, 3/4, 08739, Barcelona'},
    {'nodo': 'descarga', 'nombre': 'ES08040 Barcelona', 'direccion': 'DHL FREIGHT SPAIN S.L, C/ Atlantic 109-111  (ZAL)'},
    {'nodo': 'cargador', 'nombre': 'IONITY Palleja', 'direccion': 'Ronda de Santa Eulàlia, 31, 08780 Pallejà, Barcelona'},
    {'nodo': 'cargador', 'nombre': 'IONITY Barcera del Valles', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'IONITY Montcada i Reixac', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Nieves Zona Franca', 'direccion': ''},
    {'nodo': 'cargador', 'nombre': 'Atlante - Atlante - Nieves Sant Esteve', 'direccion': ''}
]

with open("dataset_dhl_10.pkl", "wb") as f:
    pickle.dump(datos_10, f)
